# %% [markdown]
# This is Jyupter Notebook in VS Studio

# %%
2+2
# Out:
# 4

# %%
print("Hello World!")
# Out:
# Hello World!

# %%
import math
import numpy as np
import matplotlib.pyplot as plt

x = np.arange(1,100, 5)
y = np.sin(x)
print(x,y)
plt.plot(x,y)
# Out:
# [ 1  6 11 16 21 26 31 36 41 46 51 56 61 66 71 76 81 86 91 96] [ 0.84147098 -0.2794155  -0.99999021 -0.28790332  0.83665564  0.76255845
#  -0.40403765 -0.99177885 -0.15862267  0.90178835  0.67022918 -0.521551
#  -0.96611777 -0.02655115  0.95105465  0.56610764 -0.62988799 -0.92345845
#   0.10598751  0.98358775]

# %%
import math

print ("sin(3) : ",  math.sin(3))
print ("sin(-3) : ",  math.sin(-3))
print ("sin(0) : ",  math.sin(0))
print ("sin(math.pi) : ",  math.sin(math.pi))
print ("sin(math.pi/2) : ",  math.sin(math.pi/2))
# Out:
# sin(3) :  0.1411200080598672
# sin(-3) :  -0.1411200080598672
# sin(0) :  0.0
# sin(math.pi) :  1.2246467991473532e-16
# sin(math.pi/2) :  1.0
